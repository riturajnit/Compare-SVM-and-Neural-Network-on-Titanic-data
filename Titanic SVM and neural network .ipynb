# %% [markdown]
# # Titanic: Compare Support Vector Machine to a 3 layer Neural Network

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ****Data****
#  * Survived: Survival (0 = No, 1 = Yes)
#  * PassengerId: Id given to each traveler on the boat
#  * Pclass: Ticket class. It has three possible values: 1,2,3 (first, second and third class)
#  * Sex
#  * Age
#  * Sibsp : number of siblings and spouses traveling with the passenger
#  * Parch : number of parents and children traveling with the passenger
#  * Ticket: Ticket number
#  * Fare  : Passenger fare
#  * Fabin : Cabin number
#  * Embarked: Port of Embarkation (C = Cherbourg, Q = Queenstown, S = Southampton)

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# * Total number of passenger is 891 and onle Age of **714** people is given

# %%
train.describe(include =['O'])
# Out:
#                            Name   Sex Ticket    Cabin Embarked
# count                       891   891    891      204      889
# unique                      891     2    681      147        3
# top     Masselmani, Mrs. Fatima  male   1601  B96 B98        S
# freq                          1   577      7        4      644

# %% [markdown]
# * Total number of Passenger is 891, out of them 577 are male.<br>
# * There are duplicate ticket number<br>
# * Some cabins are shared with  more than one person.

# %%
# train.describe(include ='all')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# Ticket feature may not be a correlation with survival. It contains 210 duplicates values. we may *drop ticket feature*<br>
# Cabin feature may be dropped as it is *highly incomplete* or contains many null values in training.<br>
# PassengerId may be dropped from training dataset *we need it during submission of project on kaggle*.<br>
# Name feature is relatively non-standard, *may not contribute directly to survival*, so maybe dropped.<br>
# Age of 177 people is not givenn

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.groupby('Survived').count()
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %% [markdown]
# ## Relationship between feature and survival

# %%
PassengerId_train = train['PassengerId']
# train.drop('PassengerId', axis = 1, inplace = True)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train['non_survived'] = 1-train['Survived']
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  non_survived
# 0      0         A/5 21171   7.2500   NaN        S             1
# 1      0          PC 17599  71.2833   C85        C             0
# 2      0  STON/O2. 3101282   7.9250   NaN        S             0
# 3      0            113803  53.1000  C123        S             0
# 4      0            373450   8.0500   NaN        S             1

# %% [markdown]
# ### Pclass Vs Survived

# %%
# train.groupby(by= 'Pclass').count()

# %%
# train[['Pclass', 'Survived']].groupby(['Pclass'], as_index= False).mean()\
#                                             .sort_values(by ='Survived', ascending = False)
# train.groupby(['Pclass'], as_index= False).Survived.mean().sort_values(by ='Survived', ascending = False)

# %%
pd.DataFrame({'Number of people':train.groupby('Pclass').Survived.count(), 'Survived':train.groupby('Pclass').Survived.sum(), \
              'Mean':train.groupby('Pclass').Survived.mean()})
# Out:
#         Number of people  Survived      Mean
# Pclass
# 1                    216       136  0.629630
# 2                    184        87  0.472826
# 3                    491       119  0.242363

# %%
train.groupby('Pclass').Fare.mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
# train.groupby('Pclass').Survived.sum()

# %%
print(train.Survived.sum())
print(train.Survived.mean())
# Out:
# 342
# 0.3838383838383838

# %% [markdown]
# #### Almost 38.38% i.e 342 people survived out of 891 poeple

# %%
train.groupby('Survived').size()
# Out:
# Survived
# 0    549
# 1    342
# dtype: int64

# %%
sns.barplot(x='Pclass', y= 'Survived', data = train)
# Out:
# C:\Users\04rit\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot(x= 'Pclass', y= 'Fare' , hue = 'Survived', data = train, split = True,palette={0: "r", 1: "g"})

# %%
# train.groupby('Pclass').Survived.mean().plot(kind = 'bar', )

# %% [markdown]
# Average fare of *Pclass 1* is high and also more people has survival chance from this class(136 people (63%)survived out of 216 people from Pclass 1 )<br>
# 87 people (47%) survived out of 184 people from Pclass 2 <br>
# 119 people (24%) survived out of 419 people from Pclass 3

# %% [markdown]
# ### Sex Vs Survived

# %%
# train.groupby('Sex', as_index = False).Survived.mean()

# %%
# train.groupby(by= 'Sex', as_index = False).Survived.sum()

# %%
# train.groupby('Sex').size()

# %%
pd.DataFrame({'Number of people':train.groupby('Sex').Survived.count(), 'Survived':train.groupby('Sex').Survived.sum(), \
              'Mean':train.groupby('Sex').Survived.mean()})
# Out:
#         Number of people  Survived      Mean
# Sex
# female               314       233  0.742038
# male                 577       109  0.188908

# %%
sns.barplot(x= 'Sex', y='Survived', data = train, order = ['female', 'male'])

# %%
# train.groupby('Sex').Survived.mean().plot(kind= 'bar')

# %%
train.groupby('Sex').sum()[['Survived', 'non_survived']].plot(kind = 'bar', stacked = True, figsize = (15, 5),\
                                                              color = ['g', 'r'])

# %% [markdown]
# ###### 233 female (74.2%) survived out of 314 female while only 109 male (18.8%) survived out of 577

# %% [markdown]
# ### Sex and Pclass Vs Survived

# %%
tab = pd.crosstab(train['Pclass'], train['Sex'])
tab
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
# tab1 = pd.crosstab(train['Survived'], train['Pclass'])
# tab1

# %%
# train.groupby(by = ['Sex', 'Pclass'], as_index = False)['Survived'].sum()

# %%
pd.DataFrame({'Number of people':train.groupby(by = ['Sex', 'Pclass']).Survived.count(), 'Survived':train.groupby(by = ['Sex', 'Pclass']).Survived.sum(), \
              'Mean':train.groupby(by = ['Sex', 'Pclass']).Survived.mean()})
# Out:
#                Number of people  Survived      Mean
# Sex    Pclass
# female 1                     94        91  0.968085
#        2                     76        70  0.921053
#        3                    144        72  0.500000
# male   1                    122        45  0.368852
#        2                    108        17  0.157407
#        3                    347        47  0.135447

# %%
sns.catplot(kind= 'point', x='Sex',y='Survived', hue = 'Pclass', data = train)

# %% [markdown]
# Women from 1st and 2nd Pclass has more than 90% survival chance<br>
# Men from Pclass 1 are more  survival chance and from class 2nd and 3rd have only around 10% survival chance

# %% [markdown]
# ### Age Vs Survival chance

# %%
fig= plt.figure(figsize = (15,5))
ax1 =fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3= fig.add_subplot(133)
sns.violinplot(x= 'Sex', y= 'Age' , hue = 'Survived', data = train, split = True, ax= ax1, palette={0: "r", 1: "g"})
sns.violinplot(x= 'Pclass', y= 'Age' , hue = 'Survived', data = train, split = True, ax= ax2, palette={0: "r", 1: "g"})
sns.violinplot(x= 'Embarked', y= 'Age' , hue = 'Survived', data = train, split = True, ax= ax3, palette={0: "r", 1: "g"})

# %% [markdown]
# Younger male of age range 5year - 10year tend to survive as depicted by green historam
# male of age range 20year-40year has more tend to die.
# Women survive more than men, as depicted by the larger female green histogram

# %% [markdown]
# ### Parch Vs Survival

# %%
# train.groupby('Parch').mean()

# %%
pd.DataFrame({'Number of people':train.groupby('Parch').Survived.count(), 'Survived':train.groupby('Parch').Survived.sum(), \
              'Mean':train.groupby('Parch').Survived.mean()})
# Out:
#        Number of people  Survived      Mean
# Parch
# 0                   678       233  0.343658
# 1                   118        65  0.550847
# 2                    80        40  0.500000
# 3                     5         3  0.600000
# 4                     4         0  0.000000
# 5                     5         1  0.200000
# 6                     1         0  0.000000

# %%
sns.barplot(x= 'Parch', y= 'Survived', data = train)

# %%
train.groupby('Parch')[['Survived','non_survived']].mean().plot(kind= 'bar', stacked = True, color = ('g', 'r'), figsize = (15,5))

# %% [markdown]
# Passenger with fmily member 1,2 and 3 has more survival chance.

# %% [markdown]
# ### Embarked Vs Survival

# %%
# train.Embarked.unique()

# %%
# train.groupby('Embarked').Survived.count()

# %%
pd.DataFrame({'Number of people':train.groupby('Embarked').Survived.count(), 'Survived':train.groupby('Embarked').Survived.sum(), \
              'Mean':train.groupby('Embarked').Survived.mean()})
# Out:
#           Number of people  Survived      Mean
# Embarked
# C                      168        93  0.553571
# Q                       77        30  0.389610
# S                      644       217  0.336957

# %%
# train.groupby('Embarked', as_index = False).Survived.mean()

# %%
fig = plt.figure()
train.groupby('Embarked')['Survived', 'non_survived'].sum().plot(kind = 'bar', stacked = True, color = ('g','r'))
plt.ylabel('number of people')
# Out:
# Text(0, 0.5, 'number of people')

# %% [markdown]
# More survival chance from Embarked C

# %% [markdown]
# ### SibSp Vs Survival

# %%
pd.DataFrame({'Number of people':train.groupby('SibSp').Survived.count(), 'Survived':train.groupby('SibSp').Survived.sum(), \
              'Mean':train.groupby('SibSp').Survived.mean()})
# Out:
#        Number of people  Survived      Mean
# SibSp
# 0                   608       210  0.345395
# 1                   209       112  0.535885
# 2                    28        13  0.464286
# 3                    16         4  0.250000
# 4                    18         3  0.166667
# 5                     5         0  0.000000
# 8                     7         0  0.000000

# %%
train.groupby('SibSp')['Survived', 'non_survived'].sum().plot(kind= 'bar', stacked = True, color = ('g','r'), figsize = (15,5))

# %% [markdown]
# people with less siblings has more survival chance

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# select the appropriate features totrain our classifier.

# %% [markdown]
# Combine train and test data

# %%
train_test=[train , test]
data = pd.concat(train_test, sort = False)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# 5              6       0.0       3
# 6              7       0.0       1
# 7              8       0.0       3
# 8              9       1.0       3
# 9             10       1.0       2
# 10            11       1.0       3
# 11            12       1.0       1
# 12            13       0.0       3
# 13            14       0.0       3
# 14            15       0.0       3
# 15            16       1.0       2
# 16            17       0.0       3
# 17            18       1.0       2
# 18            19       0.0       3
# 19            20       1.0       3
# 20            21       0.0       2
# 21            22       1.0       2
# 22            23       1.0       3
# 23            24       1.0       1
# 24            25       0.0       3
# 25            26       1.0       3
# 26            27       0.0       3
# 27            28       0.0       1
# 28            29       1.0       3
# 29            30       0.0       3
# ..           ...       ...     ...
# 388         1280       NaN       3
# 389         1281       NaN       3
# 390         1282       NaN       1
# 391         1283       NaN       1
# 392         1284       NaN       3
# 393         1285       NaN       2
# 394         1286       NaN       3
# 395         1287       NaN       1
# 396         1288       NaN       3
# 397         1289       NaN       1
# 398         1290       NaN       3
# 399         1291       NaN       3
# 400         1292       NaN       1
# 401         1293       NaN       2
# 402         1294       NaN       1
# 403         1295       NaN       1
# 404         1296       NaN       1
# 405         1297       NaN       2
# 406         1298       NaN       2
# 407         1299       NaN       1
# 408         1300       NaN       3
# 409         1301       NaN       3
# 410         1302       NaN       3
# 411         1303       NaN       1
# 412         1304       NaN       3
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 388                               Canavan, Mr. Patrick    male  21.0      0
# 389                        Palsson, Master. Paul Folke    male   6.0      3
# 390                         Payne, Mr. Vivian Ponsonby    male  23.0      0
# 391     Lines, Mrs. Ernest H (Elizabeth Lindsey James)  female  51.0      0
# 392                      Abbott, Master. Eugene Joseph    male  13.0      0
# 393                               Gilbert, Mr. William    male  47.0      0
# 394                           Kink-Heilmann, Mr. Anton    male  29.0      3
# 395     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)  female  18.0      1
# 396                               Colbert, Mr. Patrick    male  24.0      0
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...  female  48.0      1
# 398                     Larsson-Rondberg, Mr. Edvard A    male  22.0      0
# 399                           Conlon, Mr. Thomas Henry    male  31.0      0
# 400                            Bonnell, Miss. Caroline  female  30.0      0
# 401                                    Gale, Mr. Harry    male  38.0      1
# 402                     Gibson, Miss. Dorothy Winifred  female  22.0      0
# 403                             Carrau, Mr. Jose Pedro    male  17.0      0
# 404                       Frauenthal, Mr. Isaac Gerald    male  43.0      1
# 405       Nourney, Mr. Alfred (Baron von Drachstedt")"    male  20.0      0
# 406                          Ware, Mr. William Jeffery    male  23.0      1
# 407                         Widener, Mr. George Dunton    male  50.0      1
# 408                    Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                          Peacock, Miss. Treasteall  female   3.0      1
# 410                             Naughton, Miss. Hannah  female   NaN      0
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                     Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare        Cabin Embarked  non_survived
# 0        0           A/5 21171    7.2500          NaN        S           1.0
# 1        0            PC 17599   71.2833          C85        C           0.0
# 2        0    STON/O2. 3101282    7.9250          NaN        S           0.0
# 3        0              113803   53.1000         C123        S           0.0
# 4        0              373450    8.0500          NaN        S           1.0
# 5        0              330877    8.4583          NaN        Q           1.0
# 6        0               17463   51.8625          E46        S           1.0
# 7        1              349909   21.0750          NaN        S           1.0
# 8        2              347742   11.1333          NaN        S           0.0
# 9        0              237736   30.0708          NaN        C           0.0
# 10       1             PP 9549   16.7000           G6        S           0.0
# 11       0              113783   26.5500         C103        S           0.0
# 12       0           A/5. 2151    8.0500          NaN        S           1.0
# 13       5              347082   31.2750          NaN        S           1.0
# 14       0              350406    7.8542          NaN        S           1.0
# 15       0              248706   16.0000          NaN        S           0.0
# 16       1              382652   29.1250          NaN        Q           1.0
# 17       0              244373   13.0000          NaN        S           0.0
# 18       0              345763   18.0000          NaN        S           1.0
# 19       0                2649    7.2250          NaN        C           0.0
# 20       0              239865   26.0000          NaN        S           1.0
# 21       0              248698   13.0000          D56        S           0.0
# 22       0              330923    8.0292          NaN        Q           0.0
# 23       0              113788   35.5000           A6        S           0.0
# 24       1              349909   21.0750          NaN        S           1.0
# 25       5              347077   31.3875          NaN        S           0.0
# 26       0                2631    7.2250          NaN        C           1.0
# 27       2               19950  263.0000  C23 C25 C27        S           1.0
# 28       0              330959    7.8792          NaN        Q           0.0
# 29       0              349216    7.8958          NaN        S           1.0
# ..     ...                 ...       ...          ...      ...           ...
# 388      0              364858    7.7500          NaN        Q           NaN
# 389      1              349909   21.0750          NaN        S           NaN
# 390      0               12749   93.5000          B24        S           NaN
# 391      1            PC 17592   39.4000          D28        S           NaN
# 392      2           C.A. 2673   20.2500          NaN        S           NaN
# 393      0          C.A. 30769   10.5000          NaN        S           NaN
# 394      1              315153   22.0250          NaN        S           NaN
# 395      0               13695   60.0000          C31        S           NaN
# 396      0              371109    7.2500          NaN        Q           NaN
# 397      1               13567   79.2000          B41        C           NaN
# 398      0              347065    7.7750          NaN        S           NaN
# 399      0               21332    7.7333          NaN        Q           NaN
# 400      0               36928  164.8667           C7        S           NaN
# 401      0               28664   21.0000          NaN        S           NaN
# 402      1              112378   59.4000          NaN        C           NaN
# 403      0              113059   47.1000          NaN        S           NaN
# 404      0               17765   27.7208          D40        C           NaN
# 405      0       SC/PARIS 2166   13.8625          D38        C           NaN
# 406      0               28666   10.5000          NaN        S           NaN
# 407      1              113503  211.5000          C80        C           NaN
# 408      0              334915    7.7208          NaN        Q           NaN
# 409      1  SOTON/O.Q. 3101315   13.7750          NaN        S           NaN
# 410      0              365237    7.7500          NaN        Q           NaN
# 411      0               19928   90.0000          C78        Q           NaN
# 412      0              347086    7.7750          NaN        S           NaN
# 413      0           A.5. 3236    8.0500          NaN        S           NaN
# 414      0            PC 17758  108.9000         C105        C           NaN
# 415      0  SOTON/O.Q. 3101262    7.2500          NaN        S           NaN
# 416      0              359309    8.0500          NaN        S           NaN
# 417      1                2668   22.3583          NaN        C           NaN
#
# [1309 rows x 13 columns]

# %%
data.shape
# Out:
# (1309, 13)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# 5              6       0.0       3
# 6              7       0.0       1
# 7              8       0.0       3
# 8              9       1.0       3
# 9             10       1.0       2
# 10            11       1.0       3
# 11            12       1.0       1
# 12            13       0.0       3
# 13            14       0.0       3
# 14            15       0.0       3
# 15            16       1.0       2
# 16            17       0.0       3
# 17            18       1.0       2
# 18            19       0.0       3
# 19            20       1.0       3
# 20            21       0.0       2
# 21            22       1.0       2
# 22            23       1.0       3
# 23            24       1.0       1
# 24            25       0.0       3
# 25            26       1.0       3
# 26            27       0.0       3
# 27            28       0.0       1
# 28            29       1.0       3
# 29            30       0.0       3
# ..           ...       ...     ...
# 388         1280       NaN       3
# 389         1281       NaN       3
# 390         1282       NaN       1
# 391         1283       NaN       1
# 392         1284       NaN       3
# 393         1285       NaN       2
# 394         1286       NaN       3
# 395         1287       NaN       1
# 396         1288       NaN       3
# 397         1289       NaN       1
# 398         1290       NaN       3
# 399         1291       NaN       3
# 400         1292       NaN       1
# 401         1293       NaN       2
# 402         1294       NaN       1
# 403         1295       NaN       1
# 404         1296       NaN       1
# 405         1297       NaN       2
# 406         1298       NaN       2
# 407         1299       NaN       1
# 408         1300       NaN       3
# 409         1301       NaN       3
# 410         1302       NaN       3
# 411         1303       NaN       1
# 412         1304       NaN       3
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 388                               Canavan, Mr. Patrick    male  21.0      0
# 389                        Palsson, Master. Paul Folke    male   6.0      3
# 390                         Payne, Mr. Vivian Ponsonby    male  23.0      0
# 391     Lines, Mrs. Ernest H (Elizabeth Lindsey James)  female  51.0      0
# 392                      Abbott, Master. Eugene Joseph    male  13.0      0
# 393                               Gilbert, Mr. William    male  47.0      0
# 394                           Kink-Heilmann, Mr. Anton    male  29.0      3
# 395     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)  female  18.0      1
# 396                               Colbert, Mr. Patrick    male  24.0      0
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...  female  48.0      1
# 398                     Larsson-Rondberg, Mr. Edvard A    male  22.0      0
# 399                           Conlon, Mr. Thomas Henry    male  31.0      0
# 400                            Bonnell, Miss. Caroline  female  30.0      0
# 401                                    Gale, Mr. Harry    male  38.0      1
# 402                     Gibson, Miss. Dorothy Winifred  female  22.0      0
# 403                             Carrau, Mr. Jose Pedro    male  17.0      0
# 404                       Frauenthal, Mr. Isaac Gerald    male  43.0      1
# 405       Nourney, Mr. Alfred (Baron von Drachstedt")"    male  20.0      0
# 406                          Ware, Mr. William Jeffery    male  23.0      1
# 407                         Widener, Mr. George Dunton    male  50.0      1
# 408                    Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                          Peacock, Miss. Treasteall  female   3.0      1
# 410                             Naughton, Miss. Hannah  female   NaN      0
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                     Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare        Cabin Embarked  non_survived
# 0        0           A/5 21171    7.2500          NaN        S           1.0
# 1        0            PC 17599   71.2833          C85        C           0.0
# 2        0    STON/O2. 3101282    7.9250          NaN        S           0.0
# 3        0              113803   53.1000         C123        S           0.0
# 4        0              373450    8.0500          NaN        S           1.0
# 5        0              330877    8.4583          NaN        Q           1.0
# 6        0               17463   51.8625          E46        S           1.0
# 7        1              349909   21.0750          NaN        S           1.0
# 8        2              347742   11.1333          NaN        S           0.0
# 9        0              237736   30.0708          NaN        C           0.0
# 10       1             PP 9549   16.7000           G6        S           0.0
# 11       0              113783   26.5500         C103        S           0.0
# 12       0           A/5. 2151    8.0500          NaN        S           1.0
# 13       5              347082   31.2750          NaN        S           1.0
# 14       0              350406    7.8542          NaN        S           1.0
# 15       0              248706   16.0000          NaN        S           0.0
# 16       1              382652   29.1250          NaN        Q           1.0
# 17       0              244373   13.0000          NaN        S           0.0
# 18       0              345763   18.0000          NaN        S           1.0
# 19       0                2649    7.2250          NaN        C           0.0
# 20       0              239865   26.0000          NaN        S           1.0
# 21       0              248698   13.0000          D56        S           0.0
# 22       0              330923    8.0292          NaN        Q           0.0
# 23       0              113788   35.5000           A6        S           0.0
# 24       1              349909   21.0750          NaN        S           1.0
# 25       5              347077   31.3875          NaN        S           0.0
# 26       0                2631    7.2250          NaN        C           1.0
# 27       2               19950  263.0000  C23 C25 C27        S           1.0
# 28       0              330959    7.8792          NaN        Q           0.0
# 29       0              349216    7.8958          NaN        S           1.0
# ..     ...                 ...       ...          ...      ...           ...
# 388      0              364858    7.7500          NaN        Q           NaN
# 389      1              349909   21.0750          NaN        S           NaN
# 390      0               12749   93.5000          B24        S           NaN
# 391      1            PC 17592   39.4000          D28        S           NaN
# 392      2           C.A. 2673   20.2500          NaN        S           NaN
# 393      0          C.A. 30769   10.5000          NaN        S           NaN
# 394      1              315153   22.0250          NaN        S           NaN
# 395      0               13695   60.0000          C31        S           NaN
# 396      0              371109    7.2500          NaN        Q           NaN
# 397      1               13567   79.2000          B41        C           NaN
# 398      0              347065    7.7750          NaN        S           NaN
# 399      0               21332    7.7333          NaN        Q           NaN
# 400      0               36928  164.8667           C7        S           NaN
# 401      0               28664   21.0000          NaN        S           NaN
# 402      1              112378   59.4000          NaN        C           NaN
# 403      0              113059   47.1000          NaN        S           NaN
# 404      0               17765   27.7208          D40        C           NaN
# 405      0       SC/PARIS 2166   13.8625          D38        C           NaN
# 406      0               28666   10.5000          NaN        S           NaN
# 407      1              113503  211.5000          C80        C           NaN
# 408      0              334915    7.7208          NaN        Q           NaN
# 409      1  SOTON/O.Q. 3101315   13.7750          NaN        S           NaN
# 410      0              365237    7.7500          NaN        Q           NaN
# 411      0               19928   90.0000          C78        Q           NaN
# 412      0              347086    7.7750          NaN        S           NaN
# 413      0           A.5. 3236    8.0500          NaN        S           NaN
# 414      0            PC 17758  108.9000         C105        C           NaN
# 415      0  SOTON/O.Q. 3101262    7.2500          NaN        S           NaN
# 416      0              359309    8.0500          NaN        S           NaN
# 417      1                2668   22.3583          NaN        C           NaN
#
# [1309 rows x 13 columns]

# %% [markdown]
# ### Name

# %% [markdown]
# Extract title from each name that can give additional information about the social status

# %%
# title = []
# for name in data['Name']:
#     title.append(name.split(',')[1].split('.')[0])
# data['title'] = title

# %%
data['title'] = data['Name'].apply(lambda name: name.split(',')[1].split('.')[0].strip())
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  non_survived title
# 0      0         A/5 21171   7.2500   NaN        S           1.0    Mr
# 1      0          PC 17599  71.2833   C85        C           0.0   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0.0  Miss
# 3      0            113803  53.1000  C123        S           0.0   Mrs
# 4      0            373450   8.0500   NaN        S           1.0    Mr

# %%
# pd.crosstab(data['title'], data['Sex'])

# %%
Titles = {
    "Capt": "Officer",
    "Col": "Officer",
    "Major": "Officer",
    "Jonkheer": "Royalty",
    "Don": "Royalty",
    "Sir" : "Royalty",
    "Dr": "Officer",
    "Rev": "Officer",
    "the Countess":"Royalty",
    "Mme": "Mrs",
    "Mlle": "Miss",
    "Ms": "Mrs",
    "Mr" : "Mr",
    "Mrs" : "Mrs",
    "Miss" : "Miss",
    "Master" : "Master",
    "Lady" : "Royalty",
    "Dona": "Master"
}

# %%
data['title'] = data.title.apply(lambda x: Titles[x])

# %%
# title_dummy= pd.get_dummies(data['title'], prefix = "title")

# %%
# data = pd.concat([data, title_dummy], axis = 1)

# %%
data['title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Royalty', 'Officer'], dtype=object)

# %%
Title_map = {'Mr': 0,
             'Mrs':1,
             'Miss': 2,
             'Master':3,
             'Royalty':4,
             'Officer':5}

# %%
data['title'] = data.title.apply(lambda x: Title_map[x])

# %%
data['title'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  non_survived  title
# 0      0         A/5 21171   7.2500   NaN        S           1.0      0
# 1      0          PC 17599  71.2833   C85        C           0.0      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0.0      2
# 3      0            113803  53.1000  C123        S           0.0      1
# 4      0            373450   8.0500   NaN        S           1.0      0

# %% [markdown]
# ### Sex feature

# %%
data['Sex'] = data['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

# %% [markdown]
# ### Age

# %%
age_mean = data['Age'].mean()

# %%
age_mean
# Out:
# 29.881137667304014

# %%
data['Age'].fillna(age_mean , inplace = True)

# %% [markdown]
# ### SibSp	Parch

# %%
data['Family_size'] = data["SibSp"]+data["Parch"] +1

# %%
data.groupby(by = ['Family_size'], as_index= False).Survived.mean()
# Out:
#    Family_size  Survived
# 0            1  0.303538
# 1            2  0.552795
# 2            3  0.578431
# 3            4  0.724138
# 4            5  0.200000
# 5            6  0.136364
# 6            7  0.333333
# 7            8  0.000000
# 8           11  0.000000

# %%
data.groupby(by = ['Family_size']).Survived.mean().plot(kind = 'bar')

# %% [markdown]
# Family size with 2, 3 and 4 member has more survival chance<br>
# convert fami;y in 3 group
#  * sigleton
#  * smallfamily
#  * largefamily

# %%
Family = []
for FamilySize in data['Family_size']:
    if FamilySize==1:
        Family.append(0)
    elif (2 <= FamilySize <= 4):
        Family.append(1)
    elif ( 5<=FamilySize):
        Family.append(2)

# %%
data["Family"] = pd.Series(Family)

# %%
data.drop(['SibSp', 'Parch', 'Family_size'], axis = 1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# 5              6       0.0       3
# 6              7       0.0       1
# 7              8       0.0       3
# 8              9       1.0       3
# 9             10       1.0       2
# 10            11       1.0       3
# 11            12       1.0       1
# 12            13       0.0       3
# 13            14       0.0       3
# 14            15       0.0       3
# 15            16       1.0       2
# 16            17       0.0       3
# 17            18       1.0       2
# 18            19       0.0       3
# 19            20       1.0       3
# 20            21       0.0       2
# 21            22       1.0       2
# 22            23       1.0       3
# 23            24       1.0       1
# 24            25       0.0       3
# 25            26       1.0       3
# 26            27       0.0       3
# 27            28       0.0       1
# 28            29       1.0       3
# 29            30       0.0       3
# ..           ...       ...     ...
# 388         1280       NaN       3
# 389         1281       NaN       3
# 390         1282       NaN       1
# 391         1283       NaN       1
# 392         1284       NaN       3
# 393         1285       NaN       2
# 394         1286       NaN       3
# 395         1287       NaN       1
# 396         1288       NaN       3
# 397         1289       NaN       1
# 398         1290       NaN       3
# 399         1291       NaN       3
# 400         1292       NaN       1
# 401         1293       NaN       2
# 402         1294       NaN       1
# 403         1295       NaN       1
# 404         1296       NaN       1
# 405         1297       NaN       2
# 406         1298       NaN       2
# 407         1299       NaN       1
# 408         1300       NaN       3
# 409         1301       NaN       3
# 410         1302       NaN       3
# 411         1303       NaN       1
# 412         1304       NaN       3
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name  Sex        Age  \
# 0                              Braund, Mr. Owen Harris    0  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000
# 2                               Heikkinen, Miss. Laina    1  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000
# 4                             Allen, Mr. William Henry    0  35.000000
# 5                                     Moran, Mr. James    0  29.881138
# 6                              McCarthy, Mr. Timothy J    0  54.000000
# 7                       Palsson, Master. Gosta Leonard    0   2.000000
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.000000
# 9                  Nasser, Mrs. Nicholas (Adele Achem)    1  14.000000
# 10                     Sandstrom, Miss. Marguerite Rut    1   4.000000
# 11                            Bonnell, Miss. Elizabeth    1  58.000000
# 12                      Saundercock, Mr. William Henry    0  20.000000
# 13                         Andersson, Mr. Anders Johan    0  39.000000
# 14                Vestrom, Miss. Hulda Amanda Adolfina    1  14.000000
# 15                    Hewlett, Mrs. (Mary D Kingcome)     1  55.000000
# 16                                Rice, Master. Eugene    0   2.000000
# 17                        Williams, Mr. Charles Eugene    0  29.881138
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...    1  31.000000
# 19                             Masselmani, Mrs. Fatima    1  29.881138
# 20                                Fynney, Mr. Joseph J    0  35.000000
# 21                               Beesley, Mr. Lawrence    0  34.000000
# 22                         McGowan, Miss. Anna "Annie"    1  15.000000
# 23                        Sloper, Mr. William Thompson    0  28.000000
# 24                       Palsson, Miss. Torborg Danira    1   8.000000
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...    1  38.000000
# 26                             Emir, Mr. Farred Chehab    0  29.881138
# 27                      Fortune, Mr. Charles Alexander    0  19.000000
# 28                       O'Dwyer, Miss. Ellen "Nellie"    1  29.881138
# 29                                 Todoroff, Mr. Lalio    0  29.881138
# ..                                                 ...  ...        ...
# 388                               Canavan, Mr. Patrick    0  21.000000
# 389                        Palsson, Master. Paul Folke    0   6.000000
# 390                         Payne, Mr. Vivian Ponsonby    0  23.000000
# 391     Lines, Mrs. Ernest H (Elizabeth Lindsey James)    1  51.000000
# 392                      Abbott, Master. Eugene Joseph    0  13.000000
# 393                               Gilbert, Mr. William    0  47.000000
# 394                           Kink-Heilmann, Mr. Anton    0  29.000000
# 395     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)    1  18.000000
# 396                               Colbert, Mr. Patrick    0  24.000000
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...    1  48.000000
# 398                     Larsson-Rondberg, Mr. Edvard A    0  22.000000
# 399                           Conlon, Mr. Thomas Henry    0  31.000000
# 400                            Bonnell, Miss. Caroline    1  30.000000
# 401                                    Gale, Mr. Harry    0  38.000000
# 402                     Gibson, Miss. Dorothy Winifred    1  22.000000
# 403                             Carrau, Mr. Jose Pedro    0  17.000000
# 404                       Frauenthal, Mr. Isaac Gerald    0  43.000000
# 405       Nourney, Mr. Alfred (Baron von Drachstedt")"    0  20.000000
# 406                          Ware, Mr. William Jeffery    0  23.000000
# 407                         Widener, Mr. George Dunton    0  50.000000
# 408                    Riordan, Miss. Johanna Hannah""    1  29.881138
# 409                          Peacock, Miss. Treasteall    1   3.000000
# 410                             Naughton, Miss. Hannah    1  29.881138
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)    1  37.000000
# 412                     Henriksson, Miss. Jenny Lovisa    1  28.000000
# 413                                 Spector, Mr. Woolf    0  29.881138
# 414                       Oliva y Ocana, Dona. Fermina    1  39.000000
# 415                       Saether, Mr. Simon Sivertsen    0  38.500000
# 416                                Ware, Mr. Frederick    0  29.881138
# 417                           Peter, Master. Michael J    0  29.881138
#
#                  Ticket      Fare        Cabin Embarked  non_survived  title  \
# 0             A/5 21171    7.2500          NaN        S           1.0      0
# 1              PC 17599   71.2833          C85        C           0.0      1
# 2      STON/O2. 3101282    7.9250          NaN        S           0.0      2
# 3                113803   53.1000         C123        S           0.0      1
# 4                373450    8.0500          NaN        S           1.0      0
# 5                330877    8.4583          NaN        Q           1.0      0
# 6                 17463   51.8625          E46        S           1.0      0
# 7                349909   21.0750          NaN        S           1.0      3
# 8                347742   11.1333          NaN        S           0.0      1
# 9                237736   30.0708          NaN        C           0.0      1
# 10              PP 9549   16.7000           G6        S           0.0      2
# 11               113783   26.5500         C103        S           0.0      2
# 12            A/5. 2151    8.0500          NaN        S           1.0      0
# 13               347082   31.2750          NaN        S           1.0      0
# 14               350406    7.8542          NaN        S           1.0      2
# 15               248706   16.0000          NaN        S           0.0      1
# 16               382652   29.1250          NaN        Q           1.0      3
# 17               244373   13.0000          NaN        S           0.0      0
# 18               345763   18.0000          NaN        S           1.0      1
# 19                 2649    7.2250          NaN        C           0.0      1
# 20               239865   26.0000          NaN        S           1.0      0
# 21               248698   13.0000          D56        S           0.0      0
# 22               330923    8.0292          NaN        Q           0.0      2
# 23               113788   35.5000           A6        S           0.0      0
# 24               349909   21.0750          NaN        S           1.0      2
# 25               347077   31.3875          NaN        S           0.0      1
# 26                 2631    7.2250          NaN        C           1.0      0
# 27                19950  263.0000  C23 C25 C27        S           1.0      0
# 28               330959    7.8792          NaN        Q           0.0      2
# 29               349216    7.8958          NaN        S           1.0      0
# ..                  ...       ...          ...      ...           ...    ...
# 388              364858    7.7500          NaN        Q           NaN      0
# 389              349909   21.0750          NaN        S           NaN      3
# 390               12749   93.5000          B24        S           NaN      0
# 391            PC 17592   39.4000          D28        S           NaN      1
# 392           C.A. 2673   20.2500          NaN        S           NaN      3
# 393          C.A. 30769   10.5000          NaN        S           NaN      0
# 394              315153   22.0250          NaN        S           NaN      0
# 395               13695   60.0000          C31        S           NaN      1
# 396              371109    7.2500          NaN        Q           NaN      0
# 397               13567   79.2000          B41        C           NaN      1
# 398              347065    7.7750          NaN        S           NaN      0
# 399               21332    7.7333          NaN        Q           NaN      0
# 400               36928  164.8667           C7        S           NaN      2
# 401               28664   21.0000          NaN        S           NaN      0
# 402              112378   59.4000          NaN        C           NaN      2
# 403              113059   47.1000          NaN        S           NaN      0
# 404               17765   27.7208          D40        C           NaN      0
# 405       SC/PARIS 2166   13.8625          D38        C           NaN      0
# 406               28666   10.5000          NaN        S           NaN      0
# 407              113503  211.5000          C80        C           NaN      0
# 408              334915    7.7208          NaN        Q           NaN      2
# 409  SOTON/O.Q. 3101315   13.7750          NaN        S           NaN      2
# 410              365237    7.7500          NaN        Q           NaN      2
# 411               19928   90.0000          C78        Q           NaN      1
# 412              347086    7.7750          NaN        S           NaN      2
# 413           A.5. 3236    8.0500          NaN        S           NaN      0
# 414            PC 17758  108.9000         C105        C           NaN      3
# 415  SOTON/O.Q. 3101262    7.2500          NaN        S           NaN      0
# 416              359309    8.0500          NaN        S           NaN      0
# 417                2668   22.3583          NaN        C           NaN      3
#
#      Family
# 0         1
# 1         1
# 2         0
# 3         1
# 4         0
# 5         0
# 6         0
# 7         2
# 8         1
# 9         1
# 10        1
# 11        0
# 12        0
# 13        2
# 14        0
# 15        0
# 16        2
# 17        0
# 18        1
# 19        0
# 20        0
# 21        0
# 22        0
# 23        0
# 24        2
# 25        2
# 26        0
# 27        2
# 28        0
# 29        0
# ..      ...
# 388       0
# 389       0
# 390       1
# 391       0
# 392       1
# 393       1
# 394       1
# 395       0
# 396       0
# 397       0
# 398       0
# 399       0
# 400       0
# 401       0
# 402       1
# 403       1
# 404       0
# 405       1
# 406       0
# 407       1
# 408       0
# 409       2
# 410       0
# 411       0
# 412       1
# 413       0
# 414       0
# 415       0
# 416       1
# 417       1
#
# [1309 rows x 13 columns]

# %% [markdown]
# ### Fare

# %%
data.Fare.isnull().sum()
# Out:
# 1

# %%
data['Fare'] = data['Fare'].fillna(train['Fare'].median())

# %%
data.Fare.isnull().sum()
# Out:
# 0

# %%
data['Fare'].describe()
# Out:
# count    1309.000000
# mean       33.281086
# std        51.741500
# min         0.000000
# 25%         7.895800
# 50%        14.454200
# 75%        31.275000
# max       512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# Mean value of Fare is  aprox. 33 and 75% of fare is 31.2 <br>
# convert fare in group
#  * fare <=7.89
#  * 7.89< fare<= 14.5
#  * 14.5< fare <= 31
#  * 31< fare

# %%
data['Fare'].dtype
# Out:
# dtype('float64')

# %%
fare = []
for fares in data['Fare']:
    if fares<=7.89:
        fare.append(0)
    elif (7.89 <= fares <= 14.5):
        fare.append(1)
    elif ( 14.5< fares<=31):
        fare.append(2)
    elif (31<=fares):
        fare.append(3)

# %%
data['Fare_data'] = pd.Series(fare)

# %%
data.drop('Fare', axis = 1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# 5              6       0.0       3
# 6              7       0.0       1
# 7              8       0.0       3
# 8              9       1.0       3
# 9             10       1.0       2
# 10            11       1.0       3
# 11            12       1.0       1
# 12            13       0.0       3
# 13            14       0.0       3
# 14            15       0.0       3
# 15            16       1.0       2
# 16            17       0.0       3
# 17            18       1.0       2
# 18            19       0.0       3
# 19            20       1.0       3
# 20            21       0.0       2
# 21            22       1.0       2
# 22            23       1.0       3
# 23            24       1.0       1
# 24            25       0.0       3
# 25            26       1.0       3
# 26            27       0.0       3
# 27            28       0.0       1
# 28            29       1.0       3
# 29            30       0.0       3
# ..           ...       ...     ...
# 388         1280       NaN       3
# 389         1281       NaN       3
# 390         1282       NaN       1
# 391         1283       NaN       1
# 392         1284       NaN       3
# 393         1285       NaN       2
# 394         1286       NaN       3
# 395         1287       NaN       1
# 396         1288       NaN       3
# 397         1289       NaN       1
# 398         1290       NaN       3
# 399         1291       NaN       3
# 400         1292       NaN       1
# 401         1293       NaN       2
# 402         1294       NaN       1
# 403         1295       NaN       1
# 404         1296       NaN       1
# 405         1297       NaN       2
# 406         1298       NaN       2
# 407         1299       NaN       1
# 408         1300       NaN       3
# 409         1301       NaN       3
# 410         1302       NaN       3
# 411         1303       NaN       1
# 412         1304       NaN       3
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                               Heikkinen, Miss. Laina    1  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 4                             Allen, Mr. William Henry    0  35.000000      0
# 5                                     Moran, Mr. James    0  29.881138      0
# 6                              McCarthy, Mr. Timothy J    0  54.000000      0
# 7                       Palsson, Master. Gosta Leonard    0   2.000000      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.000000      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)    1  14.000000      1
# 10                     Sandstrom, Miss. Marguerite Rut    1   4.000000      1
# 11                            Bonnell, Miss. Elizabeth    1  58.000000      0
# 12                      Saundercock, Mr. William Henry    0  20.000000      0
# 13                         Andersson, Mr. Anders Johan    0  39.000000      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina    1  14.000000      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)     1  55.000000      0
# 16                                Rice, Master. Eugene    0   2.000000      4
# 17                        Williams, Mr. Charles Eugene    0  29.881138      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...    1  31.000000      1
# 19                             Masselmani, Mrs. Fatima    1  29.881138      0
# 20                                Fynney, Mr. Joseph J    0  35.000000      0
# 21                               Beesley, Mr. Lawrence    0  34.000000      0
# 22                         McGowan, Miss. Anna "Annie"    1  15.000000      0
# 23                        Sloper, Mr. William Thompson    0  28.000000      0
# 24                       Palsson, Miss. Torborg Danira    1   8.000000      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...    1  38.000000      1
# 26                             Emir, Mr. Farred Chehab    0  29.881138      0
# 27                      Fortune, Mr. Charles Alexander    0  19.000000      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"    1  29.881138      0
# 29                                 Todoroff, Mr. Lalio    0  29.881138      0
# ..                                                 ...  ...        ...    ...
# 388                               Canavan, Mr. Patrick    0  21.000000      0
# 389                        Palsson, Master. Paul Folke    0   6.000000      3
# 390                         Payne, Mr. Vivian Ponsonby    0  23.000000      0
# 391     Lines, Mrs. Ernest H (Elizabeth Lindsey James)    1  51.000000      0
# 392                      Abbott, Master. Eugene Joseph    0  13.000000      0
# 393                               Gilbert, Mr. William    0  47.000000      0
# 394                           Kink-Heilmann, Mr. Anton    0  29.000000      3
# 395     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)    1  18.000000      1
# 396                               Colbert, Mr. Patrick    0  24.000000      0
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...    1  48.000000      1
# 398                     Larsson-Rondberg, Mr. Edvard A    0  22.000000      0
# 399                           Conlon, Mr. Thomas Henry    0  31.000000      0
# 400                            Bonnell, Miss. Caroline    1  30.000000      0
# 401                                    Gale, Mr. Harry    0  38.000000      1
# 402                     Gibson, Miss. Dorothy Winifred    1  22.000000      0
# 403                             Carrau, Mr. Jose Pedro    0  17.000000      0
# 404                       Frauenthal, Mr. Isaac Gerald    0  43.000000      1
# 405       Nourney, Mr. Alfred (Baron von Drachstedt")"    0  20.000000      0
# 406                          Ware, Mr. William Jeffery    0  23.000000      1
# 407                         Widener, Mr. George Dunton    0  50.000000      1
# 408                    Riordan, Miss. Johanna Hannah""    1  29.881138      0
# 409                          Peacock, Miss. Treasteall    1   3.000000      1
# 410                             Naughton, Miss. Hannah    1  29.881138      0
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)    1  37.000000      1
# 412                     Henriksson, Miss. Jenny Lovisa    1  28.000000      0
# 413                                 Spector, Mr. Woolf    0  29.881138      0
# 414                       Oliva y Ocana, Dona. Fermina    1  39.000000      0
# 415                       Saether, Mr. Simon Sivertsen    0  38.500000      0
# 416                                Ware, Mr. Frederick    0  29.881138      0
# 417                           Peter, Master. Michael J    0  29.881138      1
#
#      Parch              Ticket        Cabin Embarked  non_survived  title  \
# 0        0           A/5 21171          NaN        S           1.0      0
# 1        0            PC 17599          C85        C           0.0      1
# 2        0    STON/O2. 3101282          NaN        S           0.0      2
# 3        0              113803         C123        S           0.0      1
# 4        0              373450          NaN        S           1.0      0
# 5        0              330877          NaN        Q           1.0      0
# 6        0               17463          E46        S           1.0      0
# 7        1              349909          NaN        S           1.0      3
# 8        2              347742          NaN        S           0.0      1
# 9        0              237736          NaN        C           0.0      1
# 10       1             PP 9549           G6        S           0.0      2
# 11       0              113783         C103        S           0.0      2
# 12       0           A/5. 2151          NaN        S           1.0      0
# 13       5              347082          NaN        S           1.0      0
# 14       0              350406          NaN        S           1.0      2
# 15       0              248706          NaN        S           0.0      1
# 16       1              382652          NaN        Q           1.0      3
# 17       0              244373          NaN        S           0.0      0
# 18       0              345763          NaN        S           1.0      1
# 19       0                2649          NaN        C           0.0      1
# 20       0              239865          NaN        S           1.0      0
# 21       0              248698          D56        S           0.0      0
# 22       0              330923          NaN        Q           0.0      2
# 23       0              113788           A6        S           0.0      0
# 24       1              349909          NaN        S           1.0      2
# 25       5              347077          NaN        S           0.0      1
# 26       0                2631          NaN        C           1.0      0
# 27       2               19950  C23 C25 C27        S           1.0      0
# 28       0              330959          NaN        Q           0.0      2
# 29       0              349216          NaN        S           1.0      0
# ..     ...                 ...          ...      ...           ...    ...
# 388      0              364858          NaN        Q           NaN      0
# 389      1              349909          NaN        S           NaN      3
# 390      0               12749          B24        S           NaN      0
# 391      1            PC 17592          D28        S           NaN      1
# 392      2           C.A. 2673          NaN        S           NaN      3
# 393      0          C.A. 30769          NaN        S           NaN      0
# 394      1              315153          NaN        S           NaN      0
# 395      0               13695          C31        S           NaN      1
# 396      0              371109          NaN        Q           NaN      0
# 397      1               13567          B41        C           NaN      1
# 398      0              347065          NaN        S           NaN      0
# 399      0               21332          NaN        Q           NaN      0
# 400      0               36928           C7        S           NaN      2
# 401      0               28664          NaN        S           NaN      0
# 402      1              112378          NaN        C           NaN      2
# 403      0              113059          NaN        S           NaN      0
# 404      0               17765          D40        C           NaN      0
# 405      0       SC/PARIS 2166          D38        C           NaN      0
# 406      0               28666          NaN        S           NaN      0
# 407      1              113503          C80        C           NaN      0
# 408      0              334915          NaN        Q           NaN      2
# 409      1  SOTON/O.Q. 3101315          NaN        S           NaN      2
# 410      0              365237          NaN        Q           NaN      2
# 411      0               19928          C78        Q           NaN      1
# 412      0              347086          NaN        S           NaN      2
# 413      0           A.5. 3236          NaN        S           NaN      0
# 414      0            PC 17758         C105        C           NaN      3
# 415      0  SOTON/O.Q. 3101262          NaN        S           NaN      0
# 416      0              359309          NaN        S           NaN      0
# 417      1                2668          NaN        C           NaN      3
#
#      Family_size  Family  Fare_data
# 0              2       1          0
# 1              2       1          3
# 2              1       0          1
# 3              2       1          3
# 4              1       0          1
# 5              1       0          1
# 6              1       0          3
# 7              5       2          2
# 8              3       1          1
# 9              2       1          2
# 10             3       1          2
# 11             1       0          2
# 12             1       0          1
# 13             7       2          3
# 14             1       0          0
# 15             1       0          2
# 16             6       2          2
# 17             1       0          1
# 18             2       1          2
# 19             1       0          0
# 20             1       0          2
# 21             1       0          1
# 22             1       0          1
# 23             1       0          3
# 24             5       2          2
# 25             7       2          3
# 26             1       0          0
# 27             6       2          3
# 28             1       0          0
# 29             1       0          1
# ..           ...     ...        ...
# 388            1       0          0
# 389            5       0          1
# 390            1       1          3
# 391            2       0          0
# 392            3       1          1
# 393            1       1          3
# 394            5       1          2
# 395            2       0          0
# 396            1       0          0
# 397            3       0          2
# 398            1       0          1
# 399            1       0          1
# 400            1       0          1
# 401            2       0          1
# 402            2       1          1
# 403            1       1          2
# 404            2       0          1
# 405            1       1          2
# 406            2       0          0
# 407            3       1          2
# 408            1       0          0
# 409            3       2          2
# 410            1       0          1
# 411            2       0          0
# 412            1       1          3
# 413            1       0          0
# 414            1       0          1
# 415            1       0          1
# 416            1       1          3
# 417            3       1          1
#
# [1309 rows x 16 columns]

# %% [markdown]
# ### Embarked

# %%
data.Embarked.describe()
# Out:
# count     1307
# unique       3
# top          S
# freq       914
# Name: Embarked, dtype: object

# %%
data.Embarked.isnull().sum()
# Out:
# 2

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# Fill 2 null Embarked value with most frequent valu **S**

# %%
data['Embarked'].fillna('S', inplace = True)

# %%
data['Embarked'] = data['Embarked'].map({'S': 0, 'C': 1, 'Q':2})

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked  non_survived  title  \
# 0         A/5 21171   7.2500   NaN         0           1.0      0
# 1          PC 17599  71.2833   C85         1           0.0      1
# 2  STON/O2. 3101282   7.9250   NaN         0           0.0      2
# 3            113803  53.1000  C123         0           0.0      1
# 4            373450   8.0500   NaN         0           1.0      0
#
#    Family_size  Family  Fare_data
# 0            2       1          0
# 1            2       1          3
# 2            1       0          1
# 3            2       1          3
# 4            1       0          1

# %%
data.shape
# Out:
# (1309, 17)

# %% [markdown]
# data includes both train and test set, we need to sepereate train and test data. our train data is 891 and rest 418 is test data

# %% [markdown]
# ## Feature selections

# %%
train_feature = data[:891]

# %%
test_feature = data[891:]

# %%
train.shape, test.shape, train_feature.shape, test_feature.shape
# Out:
# ((891, 13), (418, 11), (891, 17), (418, 17))

# %%
train_feature.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked  non_survived  title  \
# 0         A/5 21171   7.2500   NaN         0           1.0      0
# 1          PC 17599  71.2833   C85         1           0.0      1
# 2  STON/O2. 3101282   7.9250   NaN         0           0.0      2
# 3            113803  53.1000  C123         0           0.0      1
# 4            373450   8.0500   NaN         0           1.0      0
#
#    Family_size  Family  Fare_data
# 0            2       1          0
# 1            2       1          3
# 2            1       0          1
# 3            2       1          3
# 4            1       0          1

# %%
test_feature.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892       NaN       3
# 1          893       NaN       3
# 2          894       NaN       2
# 3          895       NaN       3
# 4          896       NaN       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    0  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    0  62.0      0      0
# 3                              Wirz, Mr. Albert    0  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
#
#     Ticket     Fare Cabin  Embarked  non_survived  title  Family_size  Family  \
# 0   330911   7.8292   NaN         2           NaN      0            1       1
# 1   363272   7.0000   NaN         0           NaN      1            2       1
# 2   240276   9.6875   NaN         2           NaN      0            1       0
# 3   315154   8.6625   NaN         0           NaN      0            1       1
# 4  3101298  12.2875   NaN         0           NaN      1            3       0
#
#    Fare_data
# 0          0
# 1          3
# 2          1
# 3          3
# 4          1

# %% [markdown]
# #### Train data

# %%
train_data = train_feature.drop(['PassengerId','Name','Ticket','Fare', 'Cabin','non_survived', 'Family_size'], axis = 1)

# %%
train_data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch  Embarked  title  Family  \
# 0       0.0       3    0  22.0      1      0         0      0       1
# 1       1.0       1    1  38.0      1      0         1      1       1
# 2       1.0       3    1  26.0      0      0         0      2       0
# 3       1.0       1    1  35.0      1      0         0      1       1
# 4       0.0       3    0  35.0      0      0         0      0       0
#
#    Fare_data
# 0          0
# 1          3
# 2          1
# 3          3
# 4          1

# %%
train_y = train_data['Survived']
train_X = train_data.drop(['Survived'], axis =1)

# %%
train_X.shape, train_y.shape
# Out:
# ((891, 9), (891,))

# %%
train_X.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch  Embarked  title  Family  Fare_data
# 0       3    0  22.0      1      0         0      0       1          0
# 1       1    1  38.0      1      0         1      1       1          3
# 2       3    1  26.0      0      0         0      2       0          1
# 3       1    1  35.0      1      0         0      1       1          3
# 4       3    0  35.0      0      0         0      0       0          1

# %%
train_y.head()
# Out:
# 0    0.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    0.0
# Name: Survived, dtype: float64

# %% [markdown]
# #### Test data

# %%
test_data = test_feature.drop(['PassengerId','Name','Ticket','Fare','Survived', 'Cabin','non_survived','Family_size'], axis = 1)

# %%
test_data.shape
# Out:
# (418, 9)

# %%
test_data.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch  Embarked  title  Family  Fare_data
# 0       3    0  34.5      0      0         2      0       1          0
# 1       3    1  47.0      1      0         0      1       1          3
# 2       2    0  62.0      0      0         2      0       0          1
# 3       3    0  27.0      0      0         0      0       1          3
# 4       3    1  22.0      1      1         0      1       0          1

# %% [markdown]
# # Modeling

# %% [markdown]
# ### SVM and 3 layer Neural network

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(train_X, train_y, test_size = 0.1,random_state=4)

# %%
X_train.shape, X_val.shape
# Out:
# ((801, 9), (90, 9))

# %%
svm_clf = SVC(kernel='rbf')
svm_clf.fit(train_X, train_y)
svm_clf.predict(test_data)
acc_svc = svm_clf.score(train_X, train_y) 
print (acc_svc)
# Out:
# 0.8720538720538721
# C:\Users\04rit\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
svm_clf = SVC(kernel='linear')
svm_clf.fit(train_X, train_y)
svm_clf.predict(test_data)
acc_svc = svm_clf.score(train_X, train_y)
print (acc_svc)
# Out:
# 0.7867564534231201
